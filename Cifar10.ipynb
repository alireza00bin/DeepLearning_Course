# %% [markdown]
# ## Import Essential Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Load Cifar10 Dataset from keras

# %%
from tensorflow import keras
from keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print(X_train.shape) 
print(y_train.shape) 
print(X_test.shape) 
print(y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 14s 0us/step
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
cifar_label = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
plt.figure(figsize=(5,5))
plt.imshow(X_train[0])
plt.title(cifar_label[y_train[0][0]])
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %% [markdown]
# ## Train Model With ANN

# %% [markdown]
# ### Flatten Data and Normalize it

# %%
X_train_norm = X_train.reshape(-1,32*32*3) / 255
X_test_norm = X_test.reshape(-1,32*32*3) / 255

# %%
print(X_train_norm.shape)
print(X_test_norm.shape)
# Out:
# (50000, 3072)
# (10000, 3072)

# %% [markdown]
# ### Create ANN Model

# %%
from keras.layers import Dense
from keras.models import Sequential
model = Sequential(
    [
        Dense(512, input_dim=X_train_norm.shape[-1], activation='relu', name='Input'),
        Dense(512, activation='relu', name='layer1'),
        Dense(1024, activation='relu', name='layer2'),
        Dense(10, activation='softmax', name='output')
    ],
    name='ANN_Model'
)
model.summary()
# Out:
# Model: "ANN_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (Dense)               (None, 512)               1573376
#
#  layer1 (Dense)              (None, 512)               262656
#
#  layer2 (Dense)              (None, 1024)              525312
#
#  output (Dense)              (None, 10)                10250
#
# =================================================================
# Total params: 2,371,594
# Trainable params: 2,371,594
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Plot Model

# %%
from keras import utils
utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Compile Model

# %% [markdown]
# For loss function We can use different types:
#
# - Categorical Cross-Entropy
# - Sparse Categorical Cross-Entropy
# - Binary Cross-Entropy
#
# Binary Cross-Entropy: If our classification is between 2 classes We use this.
#
# Sparse Categorical Cross-Entropy: If our classification is between more than 2 classes and our targets are integer number, We use this.
#
# Categorical Cross-Entropy: If our classification is between more than 2 classes and our targets are like One-hot encoding, We use this.

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train_norm, y_train, batch_size=64, epochs=30, verbose=2, validation_data=(X_test_norm, y_test))
# Out:
# Epoch 1/30
# 782/782 - 8s - loss: 1.8481 - accuracy: 0.3290 - val_loss: 1.7253 - val_accuracy: 0.3811 - 8s/epoch - 11ms/step
# Epoch 2/30
# 782/782 - 3s - loss: 1.6572 - accuracy: 0.4015 - val_loss: 1.6591 - val_accuracy: 0.4075 - 3s/epoch - 4ms/step
# Epoch 3/30
# 782/782 - 3s - loss: 1.5622 - accuracy: 0.4385 - val_loss: 1.5270 - val_accuracy: 0.4558 - 3s/epoch - 3ms/step
# Epoch 4/30
# 782/782 - 3s - loss: 1.5071 - accuracy: 0.4612 - val_loss: 1.5287 - val_accuracy: 0.4571 - 3s/epoch - 4ms/step
# Epoch 5/30
# 782/782 - 3s - loss: 1.4635 - accuracy: 0.4748 - val_loss: 1.4973 - val_accuracy: 0.4651 - 3s/epoch - 4ms/step
# Epoch 6/30
# 782/782 - 3s - loss: 1.4260 - accuracy: 0.4859 - val_loss: 1.4699 - val_accuracy: 0.4796 - 3s/epoch - 3ms/step
# Epoch 7/30
# 782/782 - 3s - loss: 1.3815 - accuracy: 0.5078 - val_loss: 1.4553 - val_accuracy: 0.4888 - 3s/epoch - 3ms/step
# Epoch 8/30
# 782/782 - 3s - loss: 1.3580 - accuracy: 0.5118 - val_loss: 1.4461 - val_accuracy: 0.4834 - 3s/epoch - 4ms/step
# Epoch 9/30
# 782/782 - 3s - loss: 1.3212 - accuracy: 0.5264 - val_loss: 1.4160 - val_accuracy: 0.4977 - 3s/epoch - 4ms/step
# Epoch 10/30
# 782/782 - 4s - loss: 1.2832 - accuracy: 0.5357 - val_loss: 1.4695 - val_accuracy: 0.4784 - 4s/epoch - 5ms/step
# Epoch 11/30
# 782/782 - 3s - loss: 1.2490 - accuracy: 0.5478 - val_loss: 1.4795 - val_accuracy: 0.4784 - 3s/epoch - 4ms/step
# Epoch 12/30
# 782/782 - 3s - loss: 1.2134 - accuracy: 0.5608 - val_loss: 1.4709 - val_accuracy: 0.4859 - 3s/epoch - 3ms/step
# Epoch 13/30
# 782/782 - 3s - loss: 1.1772 - accuracy: 0.5743 - val_loss: 1.4584 - val_accuracy: 0.4905 - 3s/epoch - 4ms/step
# Epoch 14/30
# 782/782 - 3s - loss: 1.1278 - accuracy: 0.5919 - val_loss: 1.4652 - val_accuracy: 0.4959 - 3s/epoch - 3ms/step
# Epoch 15/30
# 782/782 - 3s - loss: 1.0877 - accuracy: 0.6053 - val_loss: 1.5283 - val_accuracy: 0.4770 - 3s/epoch - 4ms/step
# Epoch 16/30
# 782/782 - 3s - loss: 1.0382 - accuracy: 0.6227 - val_loss: 1.5387 - val_accuracy: 0.4903 - 3s/epoch - 3ms/step
# Epoch 17/30
# 782/782 - 3s - loss: 0.9864 - accuracy: 0.6411 - val_loss: 1.5518 - val_accuracy: 0.4954 - 3s/epoch - 4ms/step
# Epoch 18/30
# 782/782 - 3s - loss: 0.9469 - accuracy: 0.6553 - val_loss: 1.6196 - val_accuracy: 0.4931 - 3s/epoch - 4ms/step
# Epoch 19/30
# 782/782 - 3s - loss: 0.8924 - accuracy: 0.6763 - val_loss: 1.6438 - val_accuracy: 0.4899 - 3s/epoch - 3ms/step
# Epoch 20/30
# 782/782 - 3s - loss: 0.8399 - accuracy: 0.6934 - val_loss: 1.7351 - val_accuracy: 0.4850 - 3s/epoch - 3ms/step
# Epoch 21/30
# 782/782 - 3s - loss: 0.7958 - accuracy: 0.7089 - val_loss: 1.8274 - val_accuracy: 0.4769 - 3s/epoch - 4ms/step
# Epoch 22/30
# 782/782 - 4s - loss: 0.7487 - accuracy: 0.7258 - val_loss: 1.9096 - val_accuracy: 0.4904 - 4s/epoch - 4ms/step
# Epoch 23/30
# 782/782 - 3s - loss: 0.7024 - accuracy: 0.7446 - val_loss: 1.8992 - val_accuracy: 0.4871 - 3s/epoch - 4ms/step
# Epoch 24/30
# 782/782 - 3s - loss: 0.6624 - accuracy: 0.7587 - val_loss: 2.1165 - val_accuracy: 0.4761 - 3s/epoch - 3ms/step
# Epoch 25/30
# 782/782 - 3s - loss: 0.6199 - accuracy: 0.7764 - val_loss: 2.1133 - val_accuracy: 0.4826 - 3s/epoch - 4ms/step
# Epoch 26/30
# 782/782 - 3s - loss: 0.5819 - accuracy: 0.7887 - val_loss: 2.2841 - val_accuracy: 0.4757 - 3s/epoch - 4ms/step
# Epoch 27/30
# 782/782 - 3s - loss: 0.5612 - accuracy: 0.7974 - val_loss: 2.4310 - val_accuracy: 0.4730 - 3s/epoch - 4ms/step
# Epoch 28/30
# 782/782 - 3s - loss: 0.5113 - accuracy: 0.8133 - val_loss: 2.4635 - val_accuracy: 0.4742 - 3s/epoch - 3ms/step
# Epoch 29/30
# 782/782 - 3s - loss: 0.4936 - accuracy: 0.8219 - val_loss: 2.5936 - val_accuracy: 0.4665 - 3s/epoch - 4ms/step
# Epoch 30/30
# 782/782 - 3s - loss: 0.4703 - accuracy: 0.8325 - val_loss: 2.6593 - val_accuracy: 0.4770 - 3s/epoch - 4ms/step

# %% [markdown]
# ### Plot Model Loss

# %%
import matplotlib.pyplot as plt
f = plt.figure(figsize=(15,7.5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],
         label='train accuracy',
         c='orange', ls='-')
plt.plot(history.history['val_accuracy'],
         label='test accuracy',
         c='dodgerblue', ls='-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.subplot(1,2,2)
plt.plot(history.history['loss'],
         label='train loss',
         c='orange', ls='--')
plt.plot(history.history['val_loss'],
         label='test loss',
         c='dodgerblue', ls='--')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Measure Accuracy

# %%
loss, accuracy = model.evaluate(X_test_norm, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.6593 - accuracy: 0.4770
# Accuracy: 47.70

# %% [markdown]
# ## Train With CNN

# %%
X_train_norm = X_train / 255
X_test_norm = X_test / 255

# %% [markdown]
# Note that We just want to see the difference between ANN and CNN. For better results, You can add more layers to your model

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPool2D
model = Sequential(
    [
        Conv2D(32, (3,3), input_shape=(32,32,3), activation='relu', name='Input'),
        Conv2D(32, (3,3), activation='relu', name='Conv1'),
        Conv2D(32, (3,3), activation='relu', name='Conv2'),
        MaxPool2D((2,2), name='MaxPooling'),
        Flatten(name='Flatten'),
        Dense(64, activation='relu', name='Layer1'),
        Dense(32, activation='relu', name='Layer2'),
        Dense(10, activation='softmax', name='Output'),
    ],
    name='CNN_Model'
)
model.summary()
# Out:
# Model: "CNN_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (Conv2D)              (None, 30, 30, 32)        896
#
#  Conv1 (Conv2D)              (None, 28, 28, 32)        9248
#
#  Conv2 (Conv2D)              (None, 26, 26, 32)        9248
#
#  MaxPooling (MaxPooling2D)   (None, 13, 13, 32)        0
#
#  Flatten (Flatten)           (None, 5408)              0
#
#  Layer1 (Dense)              (None, 64)                346176
#
#  Layer2 (Dense)              (None, 32)                2080
#
#  Output (Dense)              (None, 10)                330
#
# =================================================================
# Total params: 367,978
# Trainable params: 367,978
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Plot Model

# %%
from keras import utils
utils.plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Compile and Fit Mdeol

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X_train_norm, y_train, batch_size=64, epochs=30, verbose=2, validation_data=(X_test_norm, y_test))
# Out:
# Epoch 1/30
# 782/782 - 12s - loss: 1.5257 - accuracy: 0.4428 - val_loss: 1.2827 - val_accuracy: 0.5376 - 12s/epoch - 15ms/step
# Epoch 2/30
# 782/782 - 4s - loss: 1.1409 - accuracy: 0.5940 - val_loss: 1.1348 - val_accuracy: 0.5914 - 4s/epoch - 5ms/step
# Epoch 3/30
# 782/782 - 5s - loss: 0.9715 - accuracy: 0.6599 - val_loss: 0.9933 - val_accuracy: 0.6510 - 5s/epoch - 6ms/step
# Epoch 4/30
# 782/782 - 4s - loss: 0.8658 - accuracy: 0.6982 - val_loss: 1.0632 - val_accuracy: 0.6358 - 4s/epoch - 5ms/step
# Epoch 5/30
# 782/782 - 4s - loss: 0.7907 - accuracy: 0.7227 - val_loss: 0.9673 - val_accuracy: 0.6662 - 4s/epoch - 5ms/step
# Epoch 6/30
# 782/782 - 4s - loss: 0.7232 - accuracy: 0.7469 - val_loss: 0.9693 - val_accuracy: 0.6764 - 4s/epoch - 6ms/step
# Epoch 7/30
# 782/782 - 4s - loss: 0.6629 - accuracy: 0.7667 - val_loss: 1.0202 - val_accuracy: 0.6694 - 4s/epoch - 5ms/step
# Epoch 8/30
# 782/782 - 4s - loss: 0.6046 - accuracy: 0.7872 - val_loss: 1.0247 - val_accuracy: 0.6645 - 4s/epoch - 5ms/step
# Epoch 9/30
# 782/782 - 5s - loss: 0.5485 - accuracy: 0.8075 - val_loss: 1.0948 - val_accuracy: 0.6583 - 5s/epoch - 6ms/step
# Epoch 10/30
# 782/782 - 4s - loss: 0.4981 - accuracy: 0.8244 - val_loss: 1.1311 - val_accuracy: 0.6599 - 4s/epoch - 5ms/step
# Epoch 11/30
# 782/782 - 4s - loss: 0.4521 - accuracy: 0.8403 - val_loss: 1.2096 - val_accuracy: 0.6568 - 4s/epoch - 5ms/step
# Epoch 12/30
# 782/782 - 4s - loss: 0.4015 - accuracy: 0.8572 - val_loss: 1.2848 - val_accuracy: 0.6540 - 4s/epoch - 6ms/step
# Epoch 13/30
# 782/782 - 4s - loss: 0.3638 - accuracy: 0.8699 - val_loss: 1.3359 - val_accuracy: 0.6551 - 4s/epoch - 5ms/step
# Epoch 14/30
# 782/782 - 4s - loss: 0.3212 - accuracy: 0.8859 - val_loss: 1.4713 - val_accuracy: 0.6475 - 4s/epoch - 5ms/step
# Epoch 15/30
# 782/782 - 5s - loss: 0.2956 - accuracy: 0.8947 - val_loss: 1.5968 - val_accuracy: 0.6459 - 5s/epoch - 6ms/step
# Epoch 16/30
# 782/782 - 4s - loss: 0.2599 - accuracy: 0.9076 - val_loss: 1.7355 - val_accuracy: 0.6456 - 4s/epoch - 6ms/step
# Epoch 17/30
# 782/782 - 5s - loss: 0.2358 - accuracy: 0.9159 - val_loss: 1.7900 - val_accuracy: 0.6390 - 5s/epoch - 6ms/step
# Epoch 18/30
# 782/782 - 4s - loss: 0.2146 - accuracy: 0.9228 - val_loss: 1.9470 - val_accuracy: 0.6360 - 4s/epoch - 5ms/step
# Epoch 19/30
# 782/782 - 4s - loss: 0.1893 - accuracy: 0.9324 - val_loss: 2.1735 - val_accuracy: 0.6345 - 4s/epoch - 5ms/step
# Epoch 20/30
# 782/782 - 4s - loss: 0.1769 - accuracy: 0.9362 - val_loss: 2.1363 - val_accuracy: 0.6308 - 4s/epoch - 6ms/step
# Epoch 21/30
# 782/782 - 4s - loss: 0.1657 - accuracy: 0.9408 - val_loss: 2.3221 - val_accuracy: 0.6316 - 4s/epoch - 5ms/step
# Epoch 22/30
# 782/782 - 4s - loss: 0.1595 - accuracy: 0.9428 - val_loss: 2.3261 - val_accuracy: 0.6310 - 4s/epoch - 5ms/step
# Epoch 23/30
# 782/782 - 4s - loss: 0.1427 - accuracy: 0.9501 - val_loss: 2.5709 - val_accuracy: 0.6275 - 4s/epoch - 6ms/step
# Epoch 24/30
# 782/782 - 4s - loss: 0.1346 - accuracy: 0.9522 - val_loss: 2.6368 - val_accuracy: 0.6328 - 4s/epoch - 5ms/step
# Epoch 25/30
# 782/782 - 4s - loss: 0.1340 - accuracy: 0.9529 - val_loss: 2.5896 - val_accuracy: 0.6332 - 4s/epoch - 5ms/step
# Epoch 26/30
# 782/782 - 5s - loss: 0.1197 - accuracy: 0.9584 - val_loss: 2.9057 - val_accuracy: 0.6254 - 5s/epoch - 6ms/step
# Epoch 27/30
# 782/782 - 4s - loss: 0.1148 - accuracy: 0.9591 - val_loss: 2.8666 - val_accuracy: 0.6245 - 4s/epoch - 6ms/step
# Epoch 28/30
# 782/782 - 5s - loss: 0.1151 - accuracy: 0.9596 - val_loss: 3.0543 - val_accuracy: 0.6266 - 5s/epoch - 6ms/step
# Epoch 29/30
# 782/782 - 5s - loss: 0.1107 - accuracy: 0.9608 - val_loss: 3.0484 - val_accuracy: 0.6252 - 5s/epoch - 6ms/step
# Epoch 30/30
# 782/782 - 5s - loss: 0.1029 - accuracy: 0.9624 - val_loss: 3.1250 - val_accuracy: 0.6280 - 5s/epoch - 6ms/step

# %% [markdown]
# #### Plot Loss and Val Loss

# %%
import matplotlib.pyplot as plt
f = plt.figure(figsize=(15,7.5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'],
         label='train accuracy',
         c='orange', ls='-')
plt.plot(history.history['val_accuracy'],
         label='test accuracy',
         c='dodgerblue', ls='-')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.subplot(1,2,2)
plt.plot(history.history['loss'],
         label='train loss',
         c='orange', ls='--')
plt.plot(history.history['val_loss'],
         label='test loss',
         c='dodgerblue', ls='--')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #### Measure Accuracy

# %%
loss, accuracy = model.evaluate(X_test_norm, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 3.1250 - accuracy: 0.6280
# Accuracy: 62.80

# %% [markdown]
# #### Predict

# %%
y_pred_cnn = model.predict(X_test_norm)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# #### Show Prediction

# %%
def gridshow(x, y, yp, n=5, mislabel=False):
  if mislabel:
    wrong_lable = np.where(yp != y)[0]
    grid = np.random.choice(wrong_lable, n**2)
    grid = grid.reshape(n, n)
  else:
    grid = np.random.randint(0, len(x), size=(n,n))

  fig, ax = plt.subplots(nrows=n, ncols=n, figsize=(2*n, 2*n))
  for i in range(n):
    for j in range(n):
      ax[i][j].imshow(x[grid[i,j]], cmap='gray')
      ax[i][j].axis('off')
      label = cifar_label[y[grid[i][j]][0]] + '|' + cifar_label[yp[grid[i][j]]]
      ax[i][j].set_title(label)

# %%
gridshow(X_test, y_test, np.argmax(y_pred_cnn, axis=1))
